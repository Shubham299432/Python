# %%
import seaborn as sns
import matplotlib.pyplot as plt
X =[1,2,3,4]
Y= [10,12,8,7]
plt.plot(X,Y)
plt.show()

# %%
import matplotlib.pyplot as plt
x= [1,2,3,4]
y=[10,20,30,40]
plt.bar( x, y, color= 'green')
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
tips = sns.load_dataset("tips")
sns.scatterplot(data= tips, x='total_bill', y = "tip", hue= 'sex')
plt.title("Scatter Plot with Hue")
plt.show()

# %%
sns.lineplot(data= tips, x = "total_bill", y = "tip")
plt.title("ABCD")
plt. show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
tips = sns.load_dataset("tips")
sns.violinplot(x='day', y="total_bill", data = tips)
plt.title("violin plot of total bill of the day")
plt.xlabel("Day of the week")
plt.ylabel("total bill")
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
tips = sns.load_dataset("tips")
corr= tips.corr(numeric_only= True)
sns.heatmap(corr, annot= True, cmap= "coolwarm")
plt.title("Correlation Heatmap")
plt.show()

# %%
import pandas as pd
import numpy as np
data = {'SALARY': [ 1000,1200,1300,1350,1100,25000]}
df = pd.DataFrame (data)
df
# Out:
#    SALARY
# 0    1000
# 1    1200
# 2    1300
# 3    1350
# 4    1100
# 5   25000

# %%
from sklearn.preprocessing import LabelEncoder
data =['skyblue', 'violet','red']

# %%
from sklearn.preprocessing import MinMaxScaler
import pandas as pd
data = {'Age':[22,25,47,52,46]}
df = pd.DataFrame (data)
df
# Out:
#    Age
# 0   22
# 1   25
# 2   47
# 3   52
# 4   46

# %%
scaler = MinMaxScaler()
Scaled_data = scaler.fit_transform (df)
Scaled_data
# Out:
# array([[0.        ],
#        [0.1       ],
#        [0.83333333],
#        [1.        ],
#        [0.8       ]])

# %%
print ("Hello World")
# Out:
# Hello World

# %%
fruits= ["Apple", "Bannna", "Cherry","Orange"]
for fruit in fruits:
    print(fruit)
# Out:
# Apple
# Bannna
# Cherry
# Orange

# %%
def calculate (a,b):
    return a+b, a-b, a*b
sum_, diff, prod = calculate(10,5)
print("Sum:", sum_)
print("Difference:", diff)
print("product:", prod)
# Out:
# Sum: 15
# Difference: 5
# product: 50

# %%
#Dictionary of names and ages

# %%
people = {
    "Alice": 25,
    "Bob": 30,
    "Charlie": 22
}
for name, age in people.items():
    print(f"{name} is{age} years old.")
# Out:
# Alice is25 years old.
# Bob is30 years old.
# Charlie is22 years old.

# %%
#promt user for name and age, print a message

# %%
#Funtion that returns a string in uppercase

# %%
def to_uppercase(text):
    return text.upper()
print(to_uppercase("hello world"))

# %%
print ("Hello")
# Out:
# Hello

# %%
#Funtion that returns a string in uppercase

# %%
def to_uppercase(text):
    return text.upper()
print(to_uppercase("helloworld"))
# Out:
# HELLOWORLD

# %%
#Anonymous function to return product using map()
numbers = [1,2,3,4,5]
doubled = list(map(lambda x: x*2, numbers))
print(doubled)
# Out:
# [2, 4, 6, 8, 10]

# %%
nums1 = [1,2,3]
nums2 = [4,5,6]
product = list(map(lambda x, y: x*y, nums1,nums2))
print(product)
# Out:
# [4, 10, 18]

# %%
import re
def is_valid_email(email):
    pattern = r'^[\w\.-]+@[\w\.-]+\.\w{2,}$'
    return bool(re.match(pattern, email))
print(is_valid_email("test@example.com"))
print(is_valid_email("invalid@.com"))
# Out:
# True
# False

# %%
#Function to count number of vowels in a string

# %%
def count_vowels(text):
    vowels = "aeiouAEIOU"
    return sum (1 for char in text if char in vowels)
print(count_vowels("Hello World"))
# Out:
# 3

# %%
#Print each word on a new line

# %%
sentence = input("Enter a sentence:")
words = sentence.split()
for word in words:
    print(word)
